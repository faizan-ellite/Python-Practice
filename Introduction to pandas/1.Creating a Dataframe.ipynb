# %% [markdown]
# ## Pandas
#
# pandas is a powerful, open-source Python library used primarily for data manipulation, data analysis, and data cleaning. Think of it as a way to use spreadsheets (like Excel) or databases (like SQL) directly inside your Python code, but with significantly more speed and flexibility.

# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 8.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 6.7 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.6 MB 10.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 9.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 8.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## NumPy (short for Numerical Python)
# is the foundational open-source library for scientific computing and mathematical operations in Python

# %%
data = np.array([[1,4] ,[2,5],[3,6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
df =pd.DataFrame(data,index=['row1','row2','row3'],
                 columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
data1 = np.array([[2,3,7,9],[4,5,3,7],[6,6,4,2],[7,7,4,3],[8,8,6,4]])
data1
# Out:
# array([[2, 3, 7, 9],
#        [4, 5, 3, 7],
#        [6, 6, 4, 2],
#        [7, 7, 4, 3],
#        [8, 8, 6, 4]])

# %%
df1 = pd.DataFrame(data1,index=['row1','row2','row3','row4','row5'],
                   columns=['col1','col2','col3','col4'])

# %%
df1
# Out:
#       col1  col2  col3  col4
# row1     2     3     7     9
# row2     4     5     3     7
# row3     6     6     4     2
# row4     7     7     4     3
# row5     8     8     6     4

# %%
data2 = np.array([[2.333,3.555,7,9],[4,5,3,7],[6,6,4,2],[7,7,4,3],[8,8,6,4]])
data2
# Out:
# array([[2.333, 3.555, 7.   , 9.   ],
#        [4.   , 5.   , 3.   , 7.   ],
#        [6.   , 6.   , 4.   , 2.   ],
#        [7.   , 7.   , 4.   , 3.   ],
#        [8.   , 8.   , 6.   , 4.   ]])

# %%
df2 = pd.DataFrame(data2,index=['row1','row2','row3','row4','row5'],
                   columns=['col1','col2','col3','col4'])

# %%
df2
# Out:
#        col1   col2  col3  col4
# row1  2.333  3.555   7.0   9.0
# row2  4.000  5.000   3.0   7.0
# row3  6.000  6.000   4.0   2.0
# row4  7.000  7.000   4.0   3.0
# row5  8.000  8.000   6.0   4.0

# %%
states = ['Maharashtra','Telangana','Delhi','Rajasthan']
population = [129300000,83879000,38665000,23000000]

# %%
dict_states = {'States':states,'Population':population}
dict_states
# Out:
# {'States': ['Maharashtra', 'Telangana', 'Delhi', 'Rajasthan'],
#  'Population': [129300000, 83879000, 38665000, 23000000]}

# %%
India = pd.DataFrame(dict_states)

# %%
India
# Out:
#         States  Population
# 0  Maharashtra   129300000
# 1    Telangana    83879000
# 2        Delhi    38665000
# 3    Rajasthan    23000000

# %%
import pandas as pd

# %%
df =pd.read_csv(r"C:\Python\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Python\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ItsFaizan-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/02.Intro%20to%20Pandas/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/ItsFaizan-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/02.Intro%20to%20Pandas/StudentsPerformance.csv")

# %%
df2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
